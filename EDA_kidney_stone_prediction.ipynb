# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train_df = pd.read_csv("data/train.csv")

# %%
train_df.describe()
# Out:
#                id     gravity          ph         osmo        cond  \
# count  414.000000  414.000000  414.000000   414.000000  414.000000
# mean   206.500000    1.017894    5.955459   651.545894   21.437923
# std    119.655756    0.006675    0.642260   234.676567    7.514750
# min      0.000000    1.005000    4.760000   187.000000    5.100000
# 25%    103.250000    1.012000    5.530000   455.250000   15.500000
# 50%    206.500000    1.018000    5.740000   679.500000   22.200000
# 75%    309.750000    1.022000    6.280000   840.000000   27.600000
# max    413.000000    1.040000    7.940000  1236.000000   38.000000
#
#              urea        calc      target
# count  414.000000  414.000000  414.000000
# mean   278.657005    4.114638    0.444444
# std    136.442249    3.217641    0.497505
# min     10.000000    0.170000    0.000000
# 25%    170.000000    1.450000    0.000000
# 50%    277.000000    3.130000    0.000000
# 75%    385.000000    6.630000    1.000000
# ...

# %%
train_df.isna().sum()
# Out:
# id         0
# gravity    0
# ph         0
# osmo       0
# cond       0
# urea       0
# calc       0
# target     0
# dtype: int64

# %%
train_df.dtypes
# Out:
# id           int64
# gravity    float64
# ph         float64
# osmo         int64
# cond       float64
# urea         int64
# calc       float64
# target        bool
# dtype: object

# %%
train_df["target"]=train_df["target"].astype("bool")

# %%
grid_1=sns.FacetGrid(train_df,col="target")
grid_1.map(plt.hist, "ph")

# %%
grid_2=sns.FacetGrid(train_df,col="target")
grid_2.map(plt.hist, "osmo")

# %%
grid_3=sns.FacetGrid(train_df,col="target")
grid_3.map(plt.hist, "urea")

# %%
sns.heatmap(train_df.drop("id",axis=1).corr(), annot=True, cmap="RdYlBu")
# Out:
# <Axes: >

# %%
sns.displot(train_df["cond"],kde=True)

# %%
train_df["gravity"].value_counts()
# Out:
# 1.021    51
# 1.017    49
# 1.020    31
# 1.025    30
# 1.008    29
# 1.011    28
# 1.024    24
# 1.015    21
# 1.010    20
# 1.018    14
# 1.014    13
# 1.019    10
# 1.023    10
# 1.026    10
# 1.022     9
# 1.013     9
# 1.012     9
# 1.007     9
# 1.009     8
# 1.034     6
# 1.028     6
# 1.033     4
# 1.031     4
# 1.005     3
# 1.040     3
# 1.006     2
# 1.029     1
# 1.027     1
# Name: gravity, dtype: int64

# %%
sns.displot(train_df["gravity"],kde=True)

# %%
sns.jointplot(x="osmo", y="urea", kind="reg", data=train_df)

# %%
sns.jointplot(x="osmo", y="cond", kind="reg", data=train_df)

# %%
sns.jointplot(x="osmo", y="gravity", kind="reg", data=train_df)

# %%
sns.jointplot(x="calc", y="cond", kind="kde", data=train_df)

# %%
sns.jointplot(x="calc", y="gravity", kind="hex", data=train_df)

# %%
sns.pairplot(train_df,hue="target", kind="reg", diag_kind="kde", palette="colorblind")
